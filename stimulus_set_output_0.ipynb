# %%
import trimesh
import pickle
from pathlib import Path

# %%
pickle_path = Path(r"C:\Users\William\Files\OConnor\Code\Projects\objects\stimulus_set\Z\stimulus_set_ 24_03_22__12_08_50.pickle")
with open(pickle_path, "rb") as f:
    shapes = pickle.load(f)

# %% [markdown]
# Shapes Rendered

# %%
shapes[0].mesh.show()

# %% [markdown]
# Above shape is: Z_0000<br>
# b_flat-cs_round

# %%
shapes[1].mesh.show()

# %% [markdown]
# Above shape is: Z_0001<br>
# b_weak_curve-cs_round

# %%
shapes[2].mesh.show()

# %% [markdown]
# Above shape is: Z_0002<br>
# b_strong_curve-cs_round

# %%
shapes[3].mesh.show()

# %% [markdown]
# Above shape is: Z_0003<br>
# b_sharp_bend-cs_round

# %%
shapes[4].mesh.show()

# %% [markdown]
# Above shape is: Z_0004<br>
# b_hook_f-cs_round

# %%
shapes[5].mesh.show()

# %% [markdown]
# Above shape is: Z_0005<br>
# b_hook_r-cs_round

# %%
shapes[6].mesh.show()

# %% [markdown]
# Above shape is: Z_0006<br>
# b_flat-cs_concave

# %%
shapes[7].mesh.show()

# %% [markdown]
# Above shape is: Z_0007<br>
# b_flat-cs_plane

# %%
shapes[8].mesh.show()

# %% [markdown]
# Above shape is: Z_0008<br>
# b_flat-cs_convex

# %%
shapes[9].mesh.show()

# %% [markdown]
# Above shape is: Z_0009<br>
# b_flat-cs_elliptical

# %%
shapes[10].mesh.show()

# %% [markdown]
# Above shape is: Z_0010<br>
# b_weak_curve-cs_round

# %%
shapes[11].mesh.show()

# %% [markdown]
# Above shape is: Z_0011<br>
# b_weak_curve-cs_concave

# %%
shapes[12].mesh.show()

# %% [markdown]
# Above shape is: Z_0012<br>
# b_weak_curve-cs_plane

# %%
shapes[13].mesh.show()

# %% [markdown]
# Above shape is: Z_0013<br>
# b_weak_curve-cs_convex

# %%
shapes[14].mesh.show()

# %% [markdown]
# Above shape is: Z_0014<br>
# b_weak_curve-cs_elliptical

# %%
shapes[15].mesh.show()

# %% [markdown]
# Above shape is: Z_0015<br>
# b_flat-cs_round-cs_concave

# %%
shapes[16].mesh.show()

# %% [markdown]
# Above shape is: Z_0016<br>
# b_flat-cs_concave-cs_round

# %%
shapes[17].mesh.show()

# %% [markdown]
# Above shape is: Z_0017<br>
# b_flat-cs_round-cs_plane

# %%
shapes[18].mesh.show()

# %% [markdown]
# Above shape is: Z_0018<br>
# b_flat-cs_plane-cs_round

# %%
shapes[19].mesh.show()

# %% [markdown]
# Above shape is: Z_0019<br>
# b_flat-cs_round-cs_convex

# %%
shapes[20].mesh.show()

# %% [markdown]
# Above shape is: Z_0020<br>
# b_flat-cs_convex-cs_round

# %%
shapes[21].mesh.show()

# %% [markdown]
# Above shape is: Z_0021<br>
# b_flat-cs_round-cs_elliptical

# %%
shapes[22].mesh.show()

# %% [markdown]
# Above shape is: Z_0022<br>
# b_flat-cs_elliptical-cs_round

# %%
shapes[23].mesh.show()

# %% [markdown]
# Above shape is: Z_0023<br>
# b_flat-cs_elliptical-cs_concave

# %%
shapes[24].mesh.show()

# %% [markdown]
# Above shape is: Z_0024<br>
# b_flat-cs_concave-cs_elliptical

# %%
shapes[25].mesh.show()

# %% [markdown]
# Above shape is: Z_0025<br>
# b_flat-cs_elliptical-cs_plane

# %%
shapes[26].mesh.show()

# %% [markdown]
# Above shape is: Z_0026<br>
# b_flat-cs_plane-cs_elliptical

# %%
shapes[27].mesh.show()

# %% [markdown]
# Above shape is: Z_0027<br>
# b_flat-cs_elliptical-cs_convex

# %%
shapes[28].mesh.show()

# %% [markdown]
# Above shape is: Z_0028<br>
# b_flat-cs_convex-cs_elliptical

# %%
shapes[29].mesh.show()

# %% [markdown]
# Above shape is: Z_0029<br>
# b_flat-cs_round-50%-100%-150%

# %%
shapes[30].mesh.show()

# %% [markdown]
# Above shape is: Z_0030<br>
# b_flat-cs_round-150%-100%-50%

# %%
shapes[31].mesh.show()

# %% [markdown]
# Above shape is: Z_0031<br>
# b_flat-cs_round-50%-100%-200%

# %%
shapes[32].mesh.show()

# %% [markdown]
# Above shape is: Z_0032<br>
# b_flat-cs_round-200%-100%-50%

# %%
shapes[33].mesh.show()

# %% [markdown]
# Above shape is: Z_0033<br>
# b_flat-cs_round-50%-150%-50%

# %%
shapes[34].mesh.show()

# %% [markdown]
# Above shape is: Z_0034<br>
# b_flat-cs_round-150%-50%-150%

# %%
shapes[35].mesh.show()

# %% [markdown]
# Above shape is: Z_0035<br>
# b_flat-cs_elliptical-sd_sphere-rot_b_0-rot_ls_0-pos_0.33_convex

# %%
shapes[36].mesh.show()

# %% [markdown]
# Above shape is: Z_0036<br>
# b_flat-cs_elliptical-sd_sphere-rot_b_0-rot_ls_0-pos_0.66_convex

# %%
shapes[37].mesh.show()

# %% [markdown]
# Above shape is: Z_0037<br>
# b_flat-cs_elliptical-sd_sphere-rot_b_0-rot_ls_0-pos_0.33_0.66_convex

# %%
shapes[38].mesh.show()

# %% [markdown]
# Above shape is: Z_0038<br>
# b_flat-cs_elliptical-sd_sphere-rot_b_0-rot_ls_0-pos_0.33_concave

# %%
shapes[39].mesh.show()

# %% [markdown]
# Above shape is: Z_0039<br>
# b_flat-cs_elliptical-sd_sphere-rot_b_0-rot_ls_0-pos_0.66_concave

# %%
shapes[40].mesh.show()

# %% [markdown]
# Above shape is: Z_0040<br>
# b_flat-cs_elliptical-sd_sphere-rot_b_0-rot_ls_0-pos_0.33_0.66_concave

# %%
shapes[41].mesh.show()

# %% [markdown]
# Above shape is: Z_0041<br>
# b_flat-cs_elliptical-sd_ellipsoid-rot_b_0-rot_ls_0-pos_0.33_convex

# %%
shapes[42].mesh.show()

# %% [markdown]
# Above shape is: Z_0042<br>
# b_flat-cs_elliptical-sd_ellipsoid-rot_b_0-rot_ls_0-pos_0.66_convex

# %%
shapes[43].mesh.show()

# %% [markdown]
# Above shape is: Z_0043<br>
# b_flat-cs_elliptical-sd_ellipsoid-rot_b_0-rot_ls_0-pos_0.33_0.66_convex

# %%
shapes[44].mesh.show()

# %% [markdown]
# Above shape is: Z_0044<br>
# b_flat-cs_elliptical-sd_ellipsoid-rot_b_0-rot_ls_0-pos_0.33_concave

# %%
shapes[45].mesh.show()

# %% [markdown]
# Above shape is: Z_0045<br>
# b_flat-cs_elliptical-sd_ellipsoid-rot_b_0-rot_ls_0-pos_0.66_concave

# %%
shapes[46].mesh.show()

# %% [markdown]
# Above shape is: Z_0046<br>
# b_flat-cs_elliptical-sd_ellipsoid-rot_b_0-rot_ls_0-pos_0.33_0.66_concave

# %%
shapes[47].mesh.show()

# %% [markdown]
# Above shape is: Z_0047<br>
# b_flat-cs_elliptical-sd_ellipsoid-rot_b_0-rot_ls_90-pos_0.33_convex

# %%
shapes[48].mesh.show()

# %% [markdown]
# Above shape is: Z_0048<br>
# b_flat-cs_elliptical-sd_ellipsoid-rot_b_0-rot_ls_90-pos_0.66_convex

# %%
shapes[49].mesh.show()

# %% [markdown]
# Above shape is: Z_0049<br>
# b_flat-cs_elliptical-sd_ellipsoid-rot_b_0-rot_ls_90-pos_0.33_0.66_convex

# %%
shapes[50].mesh.show()

# %% [markdown]
# Above shape is: Z_0050<br>
# b_flat-cs_elliptical-sd_ellipsoid-rot_b_0-rot_ls_90-pos_0.33_concave

# %%
shapes[51].mesh.show()

# %% [markdown]
# Above shape is: Z_0051<br>
# b_flat-cs_elliptical-sd_ellipsoid-rot_b_0-rot_ls_90-pos_0.66_concave

# %%
shapes[52].mesh.show()

# %% [markdown]
# Above shape is: Z_0052<br>
# b_flat-cs_elliptical-sd_ellipsoid-rot_b_0-rot_ls_90-pos_0.33_0.66_concave

# %%
shapes[53].mesh.show()

# %% [markdown]
# Above shape is: Z_0053<br>
# b_flat-cs_elliptical-sd_cylinder-rot_b_0-rot_ls_0-pos_0.33_convex

# %%
shapes[54].mesh.show()

# %% [markdown]
# Above shape is: Z_0054<br>
# b_flat-cs_elliptical-sd_cylinder-rot_b_0-rot_ls_0-pos_0.66_convex

# %%
shapes[55].mesh.show()

# %% [markdown]
# Above shape is: Z_0055<br>
# b_flat-cs_elliptical-sd_cylinder-rot_b_0-rot_ls_0-pos_0.33_0.66_convex

# %%
shapes[56].mesh.show()

# %% [markdown]
# Above shape is: Z_0056<br>
# b_flat-cs_elliptical-sd_cylinder_spherical_top-rot_b_0-rot_ls_0-pos_0.33_convex

# %%
shapes[57].mesh.show()

# %% [markdown]
# Above shape is: Z_0057<br>
# b_flat-cs_elliptical-sd_cylinder_spherical_top-rot_b_0-rot_ls_0-pos_0.66_convex

# %%
shapes[58].mesh.show()

# %% [markdown]
# Above shape is: Z_0058<br>
# b_flat-cs_elliptical-sd_cylinder_spherical_top-rot_b_0-rot_ls_0-pos_0.33_0.66_convex

# %%
shapes[59].mesh.show()

# %% [markdown]
# Above shape is: Z_0059<br>
# b_flat-cs_elliptical-sd_curved_cylinder-rot_b_0-rot_ls_0-pos_0.33_convex

# %%
shapes[60].mesh.show()

# %% [markdown]
# Above shape is: Z_0060<br>
# b_flat-cs_elliptical-sd_curved_cylinder-rot_b_0-rot_ls_0-pos_0.66_convex

# %%
shapes[61].mesh.show()

# %% [markdown]
# Above shape is: Z_0061<br>
# b_flat-cs_elliptical-sd_curved_cylinder-rot_b_0-rot_ls_0-pos_0.33_0.66_convex

# %%
shapes[62].mesh.show()

# %% [markdown]
# Above shape is: Z_0062<br>
# b_flat-cs_elliptical-sd_curved_cylinder-rot_b_0-rot_ls_90-pos_0.33_convex

# %%
shapes[63].mesh.show()

# %% [markdown]
# Above shape is: Z_0063<br>
# b_flat-cs_elliptical-sd_curved_cylinder-rot_b_0-rot_ls_90-pos_0.66_convex

# %%
shapes[64].mesh.show()

# %% [markdown]
# Above shape is: Z_0064<br>
# b_flat-cs_elliptical-sd_curved_cylinder-rot_b_0-rot_ls_90-pos_0.33_0.66_convex

# %%
shapes[65].mesh.show()

# %% [markdown]
# Above shape is: Z_0065<br>
# b_flat-cs_elliptical-sd_curved_cylinder-rot_b_0-rot_ls_180-pos_0.33_convex

# %%
shapes[66].mesh.show()

# %% [markdown]
# Above shape is: Z_0066<br>
# b_flat-cs_elliptical-sd_curved_cylinder-rot_b_0-rot_ls_180-pos_0.66_convex

# %%
shapes[67].mesh.show()

# %% [markdown]
# Above shape is: Z_0067<br>
# b_flat-cs_elliptical-sd_curved_cylinder-rot_b_0-rot_ls_180-pos_0.33_0.66_convex

# %%
shapes[68].mesh.show()

# %% [markdown]
# Above shape is: Z_0068<br>
# b_flat-cs_elliptical-sd_curved_cylinder-rot_b_0-rot_ls_270-pos_0.33_convex

# %%
shapes[69].mesh.show()

# %% [markdown]
# Above shape is: Z_0069<br>
# b_flat-cs_elliptical-sd_curved_cylinder-rot_b_0-rot_ls_270-pos_0.66_convex

# %%
shapes[70].mesh.show()

# %% [markdown]
# Above shape is: Z_0070<br>
# b_flat-cs_elliptical-sd_curved_cylinder-rot_b_0-rot_ls_270-pos_0.33_0.66_convex

# %%
shapes[71].mesh.show()

# %% [markdown]
# Above shape is: Z_0071<br>
# b_flat-cs_elliptical-sd_cone-rot_b_0-rot_ls_0-pos_0.33_convex

# %%
shapes[72].mesh.show()

# %% [markdown]
# Above shape is: Z_0072<br>
# b_flat-cs_elliptical-sd_cone-rot_b_0-rot_ls_0-pos_0.66_convex

# %%
shapes[73].mesh.show()

# %% [markdown]
# Above shape is: Z_0073<br>
# b_flat-cs_elliptical-sd_cone-rot_b_0-rot_ls_0-pos_0.33_0.66_convex
